# %% [markdown]
# <a href="https://colab.research.google.com/github/Willian-R/Google_Colab/blob/master/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de dados - parte 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('/content/drive/My Drive/dadosparte1.csv')

# %%
correlacao = dados.corr()

# %% [markdown]
# ## Matriz de correlação de Pearson

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlacao, annot=True, cbar=False, cmap='Blues')

# %%
colunas = ['umi_m', 'mv_m', 'cinzas_m', 'c_m', 'h_m', 'o_m', 'n_m', 'a_superf_bio', 'a_micro_bio']

# %%
dados_features = pd.read_csv('/content/drive/My Drive/dadosparte1.csv', usecols=colunas)

# %%
dados_features
# Out:
#     umi_m   mv_m  cinzas_m    c_m   h_m    o_m   n_m  a_superf_bio  a_micro_bio
# 0   12.54  58.18     27.56  34.79  4.83  30.32  2.51          3.68         0.67
# 1   12.54  58.18     27.56  34.79  4.83  30.32  2.51         98.06        75.72
# 2   13.68  45.52     38.98  29.89  4.04  25.26  1.82          4.26         0.26
# 3   13.68  45.52     38.98  29.89  4.04  25.26  1.82        116.90        84.83
# 4   14.35  33.46     49.19  28.18  3.74  17.22  1.67          7.39         1.31
# 5   14.35  33.46     49.19  28.18  3.74  17.22  1.67         73.54        46.11
# 6   13.60  68.30     18.10  42.20  6.60  36.40  4.00          5.70         2.80
# 7   13.60  68.30     18.10  42.20  6.60  36.40  4.00          3.90         2.00
# 8   13.60  68.30     18.10  42.20  6.60  36.40  4.00          3.40         2.60
# 9   13.60  68.30     18.10  42.20  6.60  36.40  4.00         59.00        43.00
# 10  13.60  68.30     18.10  42.20  6.60  36.40  4.00         63.00        37.00
# ...

# %%
colunas = ['t_resid', 'tx_aquec', 'temp']

# %%
dados_target = pd.read_csv('/content/drive/My Drive/dadosparte1.csv', usecols=colunas)

# %%
dados_target
# Out:
#     t_resid  tx_aquec   temp
# 0      2.00      25.0  400.0
# 1      2.00      25.0  700.0
# 2      2.00      25.0  400.0
# 3      2.00      25.0  700.0
# 4      2.00      25.0  400.0
# 5      2.00      25.0  700.0
# 6      1.00      10.0  400.0
# 7      1.00      10.0  500.0
# 8      1.00      10.0  600.0
# 9      1.00      10.0  700.0
# 10     1.00      10.0  800.0
# 11     3.93       5.0  900.0
# 12     1.00     128.0  900.0
# 13     0.19      25.0  300.0
# 14     0.25      25.0  400.0
# 15     0.32      25.0  500.0
# 16     0.39      25.0  600.0
# 17     1.00      24.5  348.4
# 18     1.00      35.1  427.5
# 19     1.00      42.8  659.8
# 20     1.00      25.4  398.8
# 21     1.00      35.5  528.7
# 22     1.00      49.1  604.2

# %%
dados_features_vetor = dados_features.to_numpy()
dados_target_vetor = dados_target.to_numpy()
